# %% [markdown]
# # Zepto Inventory Analytics: Cleaning, KPIs and EDA
#
# Run the pipeline, inspect clean data, and review executive KPIs.

# %%
from pathlib import Path
import sys, pandas as pd
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(ROOT / 'src'))
from pipeline import clean_products, build_kpis, build_category_summary
raw = pd.read_csv(ROOT / 'data' / 'raw' / 'zepto_inventory_raw.csv')
clean = clean_products(raw)
display(raw.shape, clean.shape)
display(build_kpis(clean))
display(build_category_summary(clean).head(15))
