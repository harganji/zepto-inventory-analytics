# %% [markdown]
# # SQL Analysis and Dashboard Prep
#
# Run the pipeline, query SQLite tables, and confirm dashboard exports.

# %%
from pathlib import Path
import sqlite3, sys, pandas as pd
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(ROOT / 'src'))
from pipeline import main as run_pipeline
run_pipeline()
conn = sqlite3.connect(ROOT / 'data' / 'processed' / 'zepto_inventory.db')
display(pd.read_sql_query('SELECT * FROM kpis', conn))
display(pd.read_sql_query('SELECT * FROM category_summary ORDER BY inventory_value_rupees DESC LIMIT 10', conn))
